# %%
import numpy as np
import pandas as pd
import nltk

# %%
sms=pd.read_csv('spam.csv', encoding='latin-1')
sms.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
sms=sms.drop(["Unnamed: 2","Unnamed: 3","Unnamed: 4"],axis=1)
sms=sms.rename(columns={"v1":"label","v2":"text"})
sms.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
print(" no of rows", len(sms))
# Out:
#  no of rows 5572

# %%
sms.label.value_counts()
# Out:
# label
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
sms.describe()
# Out:
#        label                    text
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30

# %%
sms['length']=sms['text'].apply(len)
sms.head()
# Out:
#   label                                               text  length
# 0   ham  Go until jurong point, crazy.. Available only ...     111
# 1   ham                      Ok lar... Joking wif u oni...      29
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3   ham  U dun say so early hor... U c already then say...      49
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sms['length'].plot(bins=50, kind='hist',figsize=(10,7))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sms.hist(column='length', by='label', bins=50, figsize=(15,8))
# Out:
# array([<Axes: title={'center': 'ham'}>, <Axes: title={'center': 'spam'}>],
#       dtype=object)

# %%
sms.loc[:,'label']=sms.label.map({'ham':0, 'spam':1})
sms.head()
# Out:
#   label                                               text  length
# 0     0  Go until jurong point, crazy.. Available only ...     111
# 1     0                      Ok lar... Joking wif u oni...      29
# 2     1  Free entry in 2 a wkly comp to win FA Cup fina...     155
# 3     0  U dun say so early hor... U c already then say...      49
# 4     0  Nah I don't think he goes to usf, he lives aro...      61

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

count=CountVectorizer()
input=['REMINDER FROM O2: To get 2.50 pounds free call credit and details of great offers pls reply 2 this text with your valid name, house no and postcode']

text=count.fit_transform(sms['text'])

x_train, x_test, y_train, y_test= train_test_split(text, sms['label'], test_size=0.20, random_state=1)
text
# Out:
# <5572x8672 sparse matrix of type '<class 'numpy.int64'>'
# 	with 73916 stored elements in Compressed Sparse Row format>

# %%
print(x_train.shape)
print(x_test.shape)

input=text[5571]
# Out:
# (4457, 8672)
# (1115, 8672)

# %%
'''from sklearn.neural_network import MLPClassifier

model=MLPClassifier()
model.fit(x_train, y_train)'''
# Out:
# 'from sklearn.neural_network import MLPClassifier\n\nmodel=MLPClassifier()\nmodel.fit(x_train, y_train)'

# %%
sms['label'] = pd.to_numeric(sms['label'])
x_train, x_test, y_train, y_test = train_test_split(sms['text'], sms['label'], test_size=0.20, random_state=1)

from sklearn.neural_network import MLPClassifier

x_train = count.fit_transform(x_train)
x_test = count.transform(x_test)


model = MLPClassifier()
model.fit(x_train, y_train)
# Out:
# MLPClassifier()

# %%
prediction=model.predict(x_test)
print(prediction)
# Out:
# [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Multinomial NB")
print("Accuracy score: {}". format(accuracy_score(y_test, prediction)) )
print("Precision score: {}". format(precision_score(y_test, prediction)) )
print("Recall score: {}". format(recall_score(y_test, prediction)))
print("F1 score: {}". format(f1_score(y_test, prediction)))
# Out:
# Multinomial NB
# Accuracy score: 0.9937219730941704
# Precision score: 1.0
# Recall score: 0.9496402877697842
# F1 score: 0.974169741697417

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Bernoulli NB")
print("Accuracy score: {}". format(accuracy_score(y_test, prediction)) )
print("Precision score: {}". format(precision_score(y_test, prediction)) )
print("Recall score: {}". format(recall_score(y_test, prediction)))
print("F1 score: {}". format(f1_score(y_test, prediction)))
# Out:
# Bernoulli NB
# Accuracy score: 0.9937219730941704
# Precision score: 1.0
# Recall score: 0.9496402877697842
# F1 score: 0.974169741697417

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("MLP Classifier")
print("Accuracy score: {}". format(accuracy_score(y_test, prediction)) )
print("Precision score: {}". format(precision_score(y_test, prediction)) )
print("Recall score: {}". format(recall_score(y_test, prediction)))
print("F1 score: {}". format(f1_score(y_test, prediction)))
# Out:
# MLP Classifier
# Accuracy score: 0.9937219730941704
# Precision score: 1.0
# Recall score: 0.9496402877697842
# F1 score: 0.974169741697417

# %%
input
# Out:
# <1x8672 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier


count = CountVectorizer()


x_train, x_test, y_train, y_test = train_test_split(sms['text'], sms['label'], test_size=0.20, random_state=1)

x_train = count.fit_transform(x_train)
x_test = count.transform(x_test)

model = MLPClassifier()
model.fit(x_train, y_train)

input_text = "To get 2.50 pounds free call credit and details of great offers pls reply 2 this text"

input_transformed = count.transform([input_text])

prediction = model.predict(input_transformed)
print(prediction)
# Out:
# [1]

# %%
data=sms['text']
input="To get 2.50 pounds free call credit and details of great offers pls reply 2 this text"

# %%
data
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                Will Ì_ b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: text, Length: 5572, dtype: object

# %%
data.loc[len(data.index)]="hfwe ewfjb in jd eif"

# %%
data
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5568                Will Ì_ b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# 5572                                 hfwe ewfjb in jd eif
# Name: text, Length: 5573, dtype: object

# %%
text=count.fit_transform(data)

# %%
text
# Out:
# <5572x8672 sparse matrix of type '<class 'numpy.int64'>'
# 	with 73916 stored elements in Compressed Sparse Row format>

# %%
input=text[5572]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

# ... (your existing code for loading and preprocessing data) ...

# 1. Create CountVectorizer instance
count = CountVectorizer()

# 2. Perform train-test split on the text data
x_train, x_test, y_train, y_test = train_test_split(sms['text'], sms['label'], test_size=0.20, random_state=1)

# 3. Fit CountVectorizer on the training data and transform both train and test data
x_train = count.fit_transform(x_train)
x_test = count.transform(x_test)

# 4. Train the MLPClassifier
model = MLPClassifier()
model.fit(x_train, y_train)

# Assuming 'input' is your new text data for prediction
input_data = ["To get 2.50 pounds free call credit and details of great offers pls reply 2 this text"]

# 5. Transform the new input data using the same CountVectorizer
input_transformed = count.transform(input_data)  # Use the same CountVectorizer instance

# 6. Make predictions
prediction = model.predict(input_transformed)
print(prediction)
# Out:
# [1]
